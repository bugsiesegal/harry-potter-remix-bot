# %%
import sys
from numpy import array
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.utils import np_utils
sys.path.append('../src')
from keras.preprocessing.text import one_hot
# Out:
# D:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import parameters
from data_preprocess import loaddata, remove_impuritys, one_hot_encode, one_hot_decode, number_encode

# %%
books=loaddata(parameters.datapath, 1)
books[:100]
# Out:
# "Harry Potter and the Sorcerer's Stone \n\nCHAPTER ONE \n\nTHE BOY WHO LIVED \n\nMr. and Mrs. Dursley, of n"

# %%
text=remove_impuritys(books)
books[:110]
# Out:
# "Harry Potter and the Sorcerer's Stone \n\nCHAPTER ONE \n\nTHE BOY WHO LIVED \n\nMr. and Mrs. Dursley, of number four"

# %%
characters = sorted(list(set(text)))
n_to_char = {n:char for n, char in enumerate(characters)}
char_to_n = {char:n for n, char in enumerate(characters)}

# %%
X = []
Y = []
length = len(text)
seq_length = 100
for i in range(0, length-seq_length, 1):
    sequence = text[i:i + seq_length]
    label =text[i + seq_length]
    X.append([char_to_n[char] for char in sequence])
    Y.append(char_to_n[label])

# %%
X_modified = np.reshape(X, (len(X), seq_length, 1))
X_modified = X_modified / float(len(characters))
Y_modified = np_utils.to_categorical(Y)

# %%
from keras.models import Sequential
from keras.layers import *

# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=X_modified[0].shape,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256,return_sequences=True))
model.add(LSTM(256,return_sequences=True))
model.add(LSTM(256,return_sequences=True))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(128))
model.add(Dense(64))
model.add(Dense(Y_modified.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100, 256)          264192
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 256)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100, 256)          525312
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100, 256)          525312
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100, 256)          525312
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 53)                3445
# =================================================================
# Total params: 2,410,037
# Trainable params: 2,410,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train=X_modified[:int(len(X_modified)*0.8)]
y_train=Y_modified[:int(len(Y_modified)*0.8)]
x_test=X_modified[int(len(X_modified)*0.8):]
y_test=Y_modified[int(len(Y_modified)*0.8):]

# %%
model.fit(x_train, y_train, epochs=14, batch_size=125, validation_split=0.1)
# Out:
# Train on 314337 samples, validate on 34927 samples
# Epoch 1/14
# 314337/314337 [==============================] - 2121s 7ms/step - loss: 2.2971 - val_loss: 1.9461
# Epoch 2/14
# 314337/314337 [==============================] - 2101s 7ms/step - loss: 1.8382 - val_loss: 1.6479
# Epoch 3/14
# 314337/314337 [==============================] - 2101s 7ms/step - loss: 1.6530 - val_loss: 1.5643
# Epoch 4/14
# 314337/314337 [==============================] - 2104s 7ms/step - loss: 1.5402 - val_loss: 1.4970
# Epoch 5/14
# 314337/314337 [==============================] - 2096s 7ms/step - loss: 1.4622 - val_loss: 1.4809
# Epoch 6/14
# 314337/314337 [==============================] - 2107s 7ms/step - loss: 1.4057 - val_loss: 1.4442
# Epoch 7/14
# 314337/314337 [==============================] - 2101s 7ms/step - loss: 1.3496 - val_loss: 1.4148
# Epoch 8/14
# 314337/314337 [==============================] - 2118s 7ms/step - loss: 1.3072 - val_loss: 1.4307
# Epoch 9/14
# 314337/314337 [==============================] - 2109s 7ms/step - loss: 1.2708 - val_loss: 1.4493
# Epoch 10/14
# 314337/314337 [==============================] - 2113s 7ms/step - loss: 1.2337 - val_loss: 1.4194
# Epoch 11/14
# 314337/314337 [==============================] - 2113s 7ms/step - loss: 1.2036 - val_loss: 1.4137
# Epoch 12/14
# 314337/314337 [==============================] - 2102s 7ms/step - loss: 1.1734 - val_loss: 1.4212
# Epoch 13/14
# 314337/314337 [==============================] - 2115s 7ms/step - loss: 1.1444 - val_loss: 1.4821
# Epoch 14/14
# 314337/314337 [==============================] - 2110s 7ms/step - loss: 1.1222 - val_loss: 1.4563

# %%
string_mapped = X[99][:-1]
print(len(string_mapped))
full_string = [n_to_char[value] for value in string_mapped]
# generating characters
for i in range(400):
    x = np.reshape(string_mapped,(1,len(string_mapped), 1))
    print(x.shape)
    x = x / float(len(characters))

    pred_index = np.argmax(model.predict(x, verbose=0))
    seq = [n_to_char[value] for value in string_mapped]
    full_string.append(n_to_char[pred_index])

    string_mapped.append(pred_index)
    string_mapped = string_mapped[1:len(string_mapped)]
# Out:
# 100
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)
# (1, 100, 1)

# %%
full_string
# Out:
# [' ',
#  'f',
#  'o',
#  'u',
#  'r',
#  ',',
#  ' ',
#  'p',
#  'r',
#  'i',
#  'v',
#  'e',
#  't',
#  ' ',
#  'd',
#  'r',
#  'i',
#  'v',
#  'e',
#  ',',
#  ' ',
#  'w',
#  'e',
#  'r',
#  'e',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'u',
#  'd',
#  ' ',
#  't',
#  'o',
#  ' ',
#  's',
#  'a',
#  'y',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  't',
#  'h',
#  'e',
#  'y',
#  ' ',
#  'w',
#  'e',
#  'r',
#  'e',
#  ' ',
#  'p',
#  'e',
#  'r',
#  'f',
#  'e',
#  'c',
#  't',
#  'l',
#  'y',
#  ' ',
#  'n',
#  'o',
#  'r',
#  'm',
#  'a',
#  'l',
#  ',',
#  ' ',
#  't',
#  'h',
#  'a',
#  'n',
#  'k',
#  ' ',
#  'y',
#  'o',
#  'u',
#  ' ',
#  'v',
#  'e',
#  'r',
#  'y',
#  ' ',
#  'm',
#  'u',
#  'c',
#  'h',
#  '.',
#  ' ',
#  't',
#  'h',
#  'e',
#  'y',
#  ' ',
#  'w',
#  'e',
#  'r',
#  'e',
#  ' ',
#  'a',
#  'l',
#  'l',
#  ' ',
#  't',
#  'e',
#  'l',
#  'l',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'h',
#  'i',
#  'm',
#  ' ',
#  'a',
#  'n',
#  'y',
#  't',
#  'h',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'a',
#  'b',
#  'o',
#  'u',
#  't',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  's',
#  'e',
#  'a',
#  'm',
#  ' ',
#  'a',
#  'n',
#  'y',
#  't',
#  'a',
#  'y',
#  ',',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  's',
#  't',
#  'r',
#  'e',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  't',
#  'r',
#  'a',
#  'i',
#  'n',
#  ' ',
#  't',
#  'o',
#  'o',
#  'k',
#  ' ',
#  'a',
#  ' ',
#  's',
#  'o',
#  'a',
#  'r',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  's',
#  'e',
#  'a',
#  'c',
#  'h',
#  'e',
#  'd',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  's',
#  't',
#  'a',
#  'r',
#  't',
#  'i',
#  'n',
#  'g',
#  ' ',
#  't',
#  'o',
#  ' ',
#  's',
#  'e',
#  'e',
#  ' ',
#  'w',
#  'h',
#  'a',
#  't',
#  ' ',
#  'h',
#  'a',
#  'd',
#  ' ',
#  'b',
#  'e',
#  'e',
#  'n',
#  ' ',
#  'a',
#  ' ',
#  'l',
#  'o',
#  't',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  's',
#  'e',
#  'a',
#  'c',
#  'h',
#  'e',
#  'r',
#  's',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  's',
#  'e',
#  's',
#  't',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'w',
#  'a',
#  'y',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  's',
#  't',
#  'r',
#  'e',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  's',
#  't',
#  'a',
#  'r',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'a',
#  't',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'h',
#  'e',
#  'r',
#  'm',
#  'i',
#  'o',
#  'n',
#  'e',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  's',
#  't',
#  'a',
#  'r',
#  't',
#  'i',
#  'n',
#  'g',
#  ' ',
#  't',
#  'o',
#  ' ',
#  's',
#  'e',
#  'e',
#  ' ',
#  'w',
#  'h',
#  'a',
#  't',
#  ' ',
#  'h',
#  'a',
#  'd',
#  ' ',
#  'b',
#  'e',
#  'e',
#  'n',
#  ' ',
#  'a',
#  ' ',
#  'l',
#  'o',
#  't',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  's',
#  'e',
#  'a',
#  'c',
#  'h',
#  'e',
#  'r',
#  's',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  's',
#  'e',
#  's',
#  't',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'w',
#  'a',
#  'y',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  's',
#  't',
#  'r',
#  'e',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  's',
#  't',
#  'a',
#  'r',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'a',
#  't',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'h',
#  'e',
#  'r',
#  'm',
#  'i',
#  'o',
#  'n',
#  'e',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'h',
#  'a',
#  'r',
#  'r',
#  'y',
#  ' ',
#  'w',
#  'a']

# %%
txt=""
for char in full_string:
    txt = txt+char
txt
# Out:
# ' four, privet drive, were proud to say that they were perfectly normal, thank you very much. they were all telling him anything about the seam anytay, harry was stre the train took a soar and the seached harry and harry was starting to see what had been a lot of seachers and the sest of the way harry was stre the was staring at harry and hermione and harry was starting to see what had been a lot of seachers and the sest of the way harry was stre the was staring at harry and hermione and harry wa'
